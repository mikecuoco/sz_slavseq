# %% [markdown]
# # Peak calling testing

# %%
from pathlib import Path
import logging
from tqdm import tqdm
from collections import defaultdict

logging.basicConfig(level=logging.INFO)

import pysam
import pandas as pd
import pyranges as pr
import seaborn as sns
import matplotlib.pyplot as plt
from scripts.pyslavseq.sliding_window import SlidingWindow
# Out:
# INFO:numexpr.utils:Note: NumExpr detected 48 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.

# %% [markdown]
# ### Load donor data

# %%
# find knrgl bed and bulk BAMs for each individual
individuals = pd.read_csv(
    "/iblm/logglun02/mcuoco/workflows/sz_slavseq/config/7donor_donors.tsv", sep="\t"
)["donor_id"].values.astype(str)
indv_data = defaultdict(dict)
outdir = "/iblm/netapp/data4/mcuoco/sz_slavseq"

for i in individuals:
    for f in Path(f"{outdir}/results/align/{i}/").glob("gDNA*tagged.sorted.bam"):
        indv_data[i]["bulk"] = str(f)

    # convert this path to a string
    indv_data[i]["knrgl"] = str(
        Path(outdir) / "resources" / f"{i}_insertions_1kb_3end.bed"
    )

    indv_data[i]["cells"] = [
        str(f)
        for f in Path(f"{outdir}/results/align/{i}").rglob("*tagged.sorted.bam")
        if "gDNA" not in f.name
    ]

# %%
blacklist = pd.read_csv(
    "https://ftp-trace.ncbi.nlm.nih.gov/ReferenceSamples/giab/release/genome-stratifications/v3.0/GRCh38/union/GRCh38_alldifficultregions.bed.gz",
    sep="\t",
    skiprows=1,
    header=None,
    names=["Chromosome", "Start", "End"],
)

rmsk = pr.read_bed(
    "/iblm/netapp/data4/mcuoco/sz_slavseq/resources/rmsk_1kb_3end.bed", as_df=True
).sort_values(["Chromosome", "Start", "End"])

# %% [markdown]
# ## Bulk peaks

# %%
bam = pysam.AlignmentFile(indv_data["1"]["bulk"])
knrgl = pd.read_csv(indv_data["1"]["knrgl"], sep="\t")
knrgl["Name"] = "KNRGL"
line1 = pd.concat(
    [
        knrgl[["Chromosome", "Start", "End", "Name"]],
        rmsk[["Chromosome", "Start", "End", "Name"]],
    ]
).sort_values(["Chromosome", "Start", "End"])

# %% [markdown]
# ### Test Peak Callers

# %%
# speed test
import cProfile, pstats, io

with cProfile.Profile() as prof:
    spc = SlidingWindow(bam, contigs=["chr22"], min_mapq=5)
    peaks = []
    for p in spc.make_windows(
        size=200,
        step=1,
        min_rpm=2,
        strand_split=True,
        merge=True,
        features=True,
    ):
        peaks.append(p)

    s = io.StringIO()
    ps = pstats.Stats(prof, stream=s).sort_stats(pstats.SortKey.CUMULATIVE)
    ps.print_stats()
    print(s.getvalue())
# Out:
# INFO:root:4380613 filtered reads in the bam file
# INFO:root:Making windows on chr22
#          205056476 function calls (205050943 primitive calls) in 76.057 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       127    0.007    0.000   46.004    0.362 /iblm/logglun02/mcuoco/workflows/sz_slavseq/workflow/scripts/pyslavseq/sliding_window.py:263(make_windows)
#       128    0.250    0.002   45.456    0.355 /iblm/logglun02/mcuoco/workflows/sz_slavseq/workflow/scripts/pyslavseq/sliding_window.py:145(merge)
#     59252   36.409    0.001   44.880    0.001 /iblm/logglun02/mcuoco/workflows/sz_slavseq/workflow/scripts/pyslavseq/sliding_window.py:109(windows)
#         1    0.000    0.000   30.070   30.070 /iblm/logglun02/mcuoco/workflows/sz_slavseq/workflow/scripts/pyslavseq/sliding_window.py:81(__init__)
#         1    0.000    0.000   30.066   30.066 {method 'count' of 'pysam.libcalignmentfile.AlignmentFile' objects}
#         1    4.345    4.345   30.066   30.066 pysam/libcalignmentfile.pyx:1353(count)
#   8761226    5.656    0.000   13.023    0.000 /iblm/logglun02/mcuoco/workflows/sz_slavseq/workflow/scripts/pyslavseq/sliding_window.py:88(<lambda>)
#   8761227    2.901    0.000   11.735    0.000 pysam/libcalignmentfile.pyx:2255(__next__)
# 111354/111254    0.144    0.000   11.590    0.000 {built-in method builtins.next}
#   8983697    6.698    0.000    6.698    0.000 pysam/libcalignmentfile.pyx:2090(cnext)
# 101641968/101641964    6.140    0.000    6.140    0.000 {built-in method builtins.len}
#   9030130    2.004    0.000    2.536    0.000 pysam/libcalignedsegment.pyx:1625(__get__)
#   8901838    1.855    0.000    1.855    0.000 pysam/libcalignedsegment.pyx:600(makeAlignedSegment)
#  27153823    1.544    0.000    1.544    0.000 pysam/libcalignedsegment.pyx:1205(__get__)
#     32073    0.311    0.000    1.483    0.000 /iblm/logglun02/mcuoco/workflows/sz_slavseq/workflow/scripts/pyslavseq/sliding_window.py:35(read_to_namedtuple)
#   4458759    1.050    0.000    1.299    0.000 pysam/libcalignedsegment.pyx:1655(__get__)
#   4458759    1.041    0.000    1.286    0.000 pysam/libcalignedsegment.pyx:1649(__get__)
#   4458759    1.006    0.000    1.255    0.000 pysam/libcalignedsegment.pyx:1637(__get__)
#   4458759    0.937    0.000    1.187    0.000 pysam/libcalignedsegment.pyx:1572(__get__)
#   8901838    0.983    0.000    0.983    0.000 pysam/libcalignedsegment.pyx:959(__dealloc__)
#       126    0.201    0.002    0.533    0.004 /iblm/logglun02/mcuoco/workflows/sz_slavseq/workflow/scripts/pyslavseq/sliding_window.py:194(features)
#      2582    0.464    0.000    0.467    0.000 pysam/libcalignmentfile.pyx:2068(__init__)
#      2580    0.002    0.000    0.466    0.000 pysam/libcalignmentfile.pyx:2236(nextiter)
#    323430    0.079    0.000    0.333    0.000 {method 'get_tag' of 'pysam.libcalignedsegment.AlignedSegment' objects}
#    140612    0.157    0.000    0.319    0.000 /iblm/logglun02/mcuoco/workflows/sz_slavseq/workflow/scripts/pyslavseq/sliding_window.py:101(<lambda>)
#    352803    0.077    0.000    0.310    0.000 {method 'has_tag' of 'pysam.libcalignedsegment.AlignedSegment' objects}
#     59122    0.299    0.000    0.299    0.000 {method 'union' of 'set' objects}
#     32073    0.093    0.000    0.295    0.000 /iblm/logglun02/mcuoco/workflows/sz_slavseq/workflow/scripts/pyslavseq/sliding_window.py:21(isref_read)
#    219891    0.085    0.000    0.271    0.000 pysam/libcalignmentfile.pyx:2098(__next__)
#    323430    0.066    0.000    0.254    0.000 pysam/libcalignedsegment.pyx:2503(get_tag (wrapper))
# 8442/3024    0.015    0.000    0.246    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#    352803    0.070    0.000    0.233    0.000 pysam/libcalignedsegment.pyx:2494(has_tag (wrapper))
#      1008    0.001    0.000    0.190    0.000 <__array_function__ internals>:177(quantile)
#    323430    0.188    0.000    0.188    0.000 pysam/libcalignedsegment.pyx:2503(get_tag)
#      1008    0.002    0.000    0.187    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/site-packages/numpy/lib/function_base.py:4175(quantile)
#      1008    0.002    0.000    0.180    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/site-packages/numpy/lib/function_base.py:4416(_quantile_unchecked)
#      1008    0.003    0.000    0.178    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/site-packages/numpy/lib/function_base.py:3674(_ureduce)
#    352803    0.162    0.000    0.162    0.000 pysam/libcalignedsegment.pyx:2494(has_tag)
#      1008    0.002    0.000    0.156    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/site-packages/numpy/lib/function_base.py:4568(_quantile_ureduce_func)
#      1008    0.015    0.000    0.152    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/site-packages/numpy/lib/function_base.py:4636(_quantile)
#     32073    0.023    0.000    0.109    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/re.py:232(findall)
#     32073    0.027    0.000    0.054    0.000 pysam/libcalignedsegment.pyx:1212(__get__)
#     32073    0.043    0.000    0.053    0.000 pysam/libcalignedsegment.pyx:1285(__get__)
#    589862    0.047    0.000    0.047    0.000 {built-in method builtins.getattr}
#      1008    0.001    0.000    0.047    0.000 <__array_function__ internals>:177(mean)
#      1008    0.005    0.000    0.044    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3313(mean)
#     32073    0.044    0.000    0.044    0.000 {method 'findall' of 're.Pattern' objects}
#    128292    0.035    0.000    0.043    0.000 pysam/libcalignedsegment.pyx:1595(__get__)
#     32073    0.028    0.000    0.042    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/re.py:288(_compile)
#     12348    0.042    0.000    0.042    0.000 {built-in method numpy.asanyarray}
#     32073    0.022    0.000    0.040    0.000 pysam/libcalignedsegment.pyx:1318(__get__)
#      1008    0.007    0.000    0.040    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/site-packages/numpy/core/_methods.py:163(_mean)
#     32073    0.018    0.000    0.039    0.000 /iblm/logglun02/mcuoco/workflows/sz_slavseq/workflow/scripts/pyslavseq/sliding_window.py:273(<lambda>)
#     64146    0.039    0.000    0.039    0.000 pysam/libcalignmentfile.pyx:500(get_reference_name)
#     32073    0.020    0.000    0.038    0.000 <string>:1(<lambda>)
#      1008    0.017    0.000    0.033    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/site-packages/numpy/lib/function_base.py:4601(_get_indexes)
#       126    0.020    0.000    0.027    0.000 /iblm/logglun02/mcuoco/workflows/sz_slavseq/workflow/scripts/pyslavseq/sliding_window.py:152(peak_stats)
#     32073    0.011    0.000    0.025    0.000 {method 'infer_read_length' of 'pysam.libcalignedsegment.AlignedSegment' objects}
#    370567    0.025    0.000    0.025    0.000 {method 'append' of 'list' objects}
#     64146    0.020    0.000    0.025    0.000 pysam/libcalignedsegment.pyx:1554(__get__)
#      5166    0.023    0.000    0.023    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#       252    0.007    0.000    0.021    0.000 /iblm/logglun02/mcuoco/workflows/sz_slavseq/workflow/scripts/pyslavseq/sliding_window.py:64(gini)
#      1008    0.001    0.000    0.021    0.000 <__array_function__ internals>:177(any)
#      1008    0.001    0.000    0.020    0.000 <__array_function__ internals>:177(unique)
#      1764    0.005    0.000    0.020    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/site-packages/numpy/core/fromnumeric.py:69(_wrapreduction)
#     32073    0.018    0.000    0.018    0.000 {built-in method __new__ of type object at 0x56426c9555c0}
#      1008    0.017    0.000    0.017    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/site-packages/numpy/lib/function_base.py:4513(_lerp)
#      1008    0.002    0.000    0.017    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/site-packages/numpy/lib/arraysetops.py:138(unique)
#      1008    0.002    0.000    0.016    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/site-packages/numpy/core/fromnumeric.py:2307(any)
#     32073    0.013    0.000    0.016    0.000 pysam/libcalignedsegment.pyx:1669(__get__)
#     33613    0.014    0.000    0.014    0.000 {built-in method builtins.isinstance}
#      1008    0.010    0.000    0.014    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/site-packages/numpy/lib/arraysetops.py:323(_unique1d)
#     32073    0.010    0.000    0.014    0.000 pysam/libcalignedsegment.pyx:1923(infer_read_length)
#      2394    0.002    0.000    0.013    0.000 <__array_function__ internals>:177(take)
#     32073    0.010    0.000    0.012    0.000 pysam/libcalignedsegment.pyx:1631(__get__)
#      3024    0.005    0.000    0.011    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/site-packages/numpy/core/numerictypes.py:356(issubdtype)
#    111358    0.011    0.000    0.011    0.000 {method 'append' of 'collections.deque' objects}
#     32073    0.009    0.000    0.011    0.000 pysam/libcalignedsegment.pyx:1603(__get__)
#     32073    0.011    0.000    0.011    0.000 pysam/libcalignedsegment.pyx:2273(__get__)
#    110219    0.010    0.000    0.010    0.000 pysam/libcalignedsegment.pyx:1263(__get__)
#    111348    0.010    0.000    0.010    0.000 {method 'popleft' of 'collections.deque' objects}
#      2772    0.001    0.000    0.010    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/site-packages/numpy/core/_methods.py:54(_any)
#      2394    0.002    0.000    0.010    0.000 {method 'any' of 'numpy.ndarray' objects}
#      2394    0.002    0.000    0.008    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/site-packages/numpy/core/fromnumeric.py:93(take)
#      1008    0.001    0.000    0.007    0.000 <__array_function__ internals>:177(concatenate)
#     66727    0.006    0.000    0.006    0.000 pysam/libcalignmentfile.pyx:353(__bool__)
#      1008    0.006    0.000    0.006    0.000 {method 'partition' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.006    0.002 pysam/libcalignmentfile.pyx:1027(fetch)
#      6048    0.004    0.000    0.006    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/site-packages/numpy/core/numerictypes.py:282(issubclass_)
#         2    0.000    0.000    0.006    0.003 {method 'fetch' of 'pysam.libcalignmentfile.AlignmentFile' objects}
#      2394    0.002    0.000    0.006    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/site-packages/numpy/core/fromnumeric.py:51(_wrapfunc)
#      1008    0.005    0.000    0.006    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/site-packages/numpy/core/_methods.py:66(_count_reduce_items)
#     30993    0.005    0.000    0.005    0.000 {built-in method builtins.max}
#       504    0.000    0.000    0.005    0.000 <__array_function__ internals>:177(sum)
#      1008    0.005    0.000    0.005    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/site-packages/numpy/lib/function_base.py:110(<lambda>)
#       252    0.005    0.000    0.005    0.000 {built-in method numpy.array}
#         2    0.000    0.000    0.005    0.002 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/logging/__init__.py:2130(info)
#      1008    0.004    0.000    0.005    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/site-packages/numpy/lib/function_base.py:4491(_get_gamma)
#         2    0.000    0.000    0.005    0.002 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/logging/__init__.py:1467(info)
#         2    0.000    0.000    0.005    0.002 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/logging/__init__.py:1600(_log)
#      1260    0.004    0.000    0.004    0.000 {method 'sort' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.004    0.002 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/logging/__init__.py:1626(handle)
#         2    0.000    0.000    0.004    0.002 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/logging/__init__.py:1680(callHandlers)
#         2    0.000    0.000    0.004    0.002 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/logging/__init__.py:955(handle)
#       504    0.001    0.000    0.004    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/site-packages/numpy/core/fromnumeric.py:2162(sum)
#         2    0.000    0.000    0.004    0.002 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/logging/__init__.py:1088(emit)
#     32073    0.004    0.000    0.004    0.000 pysam/libcalignedsegment.pyx:1343(__get__)
#     32073    0.004    0.000    0.004    0.000 pysam/libcalignedsegment.pyx:1252(__get__)
#       252    0.000    0.000    0.004    0.000 <__array_function__ internals>:177(sort)
#       252    0.000    0.000    0.004    0.000 <__array_function__ internals>:177(amin)
#         2    0.000    0.000    0.004    0.002 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/logging/__init__.py:1077(flush)
#         2    0.000    0.000    0.004    0.002 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/site-packages/ipykernel/iostream.py:480(flush)
#         2    0.000    0.000    0.004    0.002 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/threading.py:589(wait)
#         2    0.000    0.000    0.004    0.002 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/threading.py:288(wait)
#        16    0.004    0.000    0.004    0.000 {method 'acquire' of '_thread.lock' objects}
#      1008    0.004    0.000    0.004    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/site-packages/numpy/lib/function_base.py:4437(_quantile_is_valid)
#       252    0.000    0.000    0.004    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/site-packages/numpy/core/fromnumeric.py:852(sort)
#     32073    0.004    0.000    0.004    0.000 pysam/libcalignedsegment.pyx:470(calculateQueryLengthWithHardClipping)
#      2394    0.003    0.000    0.003    0.000 {method 'take' of 'numpy.ndarray' objects}
#       378    0.001    0.000    0.003    0.000 {method 'any' of 'numpy.generic' objects}
#       252    0.001    0.000    0.003    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/site-packages/numpy/core/fromnumeric.py:2802(amin)
#     10458    0.003    0.000    0.003    0.000 {built-in method builtins.issubclass}
#      2268    0.003    0.000    0.003    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#      2016    0.002    0.000    0.002    0.000 {method 'astype' of 'numpy.ndarray' objects}
#      2583    0.002    0.000    0.002    0.000 pysam/libcalignmentfile.pyx:1991(__init__)
#         3    0.000    0.000    0.002    0.001 pysam/libchtslib.pyx:591(parse_region)
#         2    0.000    0.000    0.002    0.001 pysam/libcalignmentfile.pyx:1890(get_tid)
#         4    0.002    0.001    0.002    0.001 pysam/libcalignmentfile.pyx:523(get_tid)
#      2581    0.001    0.000    0.002    0.000 pysam/libcalignmentfile.pyx:1920(__get__)
#      1008    0.001    0.000    0.001    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#      1764    0.001    0.000    0.001    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/site-packages/numpy/core/fromnumeric.py:70(<dictcomp>)
#      2713    0.001    0.000    0.001    0.000 {method 'split' of 'str' objects}
#      1008    0.001    0.000    0.001    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/site-packages/numpy/lib/arraysetops.py:125(_unpack_tuple)
#      1008    0.001    0.000    0.001    0.000 {built-in method numpy.empty}
#      2016    0.001    0.000    0.001    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#       252    0.001    0.000    0.001    0.000 {built-in method numpy.arange}
#      1017    0.001    0.000    0.001    0.000 {built-in method builtins.hasattr}
#      1008    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#      2394    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/site-packages/numpy/core/fromnumeric.py:89(_take_dispatcher)
#       252    0.000    0.000    0.000    0.000 {method 'copy' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/sre_compile.py:783(compile)
#      1765    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#      2582    0.000    0.000    0.000    0.000 pysam/libcalignmentfile.pyx:2112(__dealloc__)
#      1013    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#      2583    0.000    0.000    0.000    0.000 pysam/libcalignmentfile.pyx:2047(__dealloc__)
#      1008    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/site-packages/numpy/core/multiarray.py:148(concatenate)
#      2587    0.000    0.000    0.000    0.000 pysam/libchtslib.pyx:306(__bool__)
#      1008    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/site-packages/numpy/lib/arraysetops.py:133(_unique_dispatcher)
#         2    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/site-packages/ipykernel/iostream.py:535(write)
#      1008    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/site-packages/numpy/lib/function_base.py:4170(_quantile_dispatcher)
#      1008    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/site-packages/numpy/core/fromnumeric.py:2302(_any_dispatcher)
#      1008    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3308(_mean_dispatcher)
#         1    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/sre_parse.py:944(parse)
#      2581    0.000    0.000    0.000    0.000 pysam/libcalignmentfile.pyx:363(__get__)
#      1008    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/site-packages/numpy/lib/function_base.py:111(<lambda>)
#      2586    0.000    0.000    0.000    0.000 pysam/libcalignmentfile.pyx:758(has_index)
#      2587    0.000    0.000    0.000    0.000 pysam/libchtslib.pyx:421(__get__)
#         6    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/site-packages/ipykernel/iostream.py:203(schedule)
#       3/1    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/sre_parse.py:436(_parse_sub)
#         2    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/site-packages/ipykernel/iostream.py:465(_schedule_flush)
#       126    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#       3/1    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/sre_parse.py:494(_parse)
#         2    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/logging/__init__.py:1585(makeRecord)
#         2    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/logging/__init__.py:283(__init__)
#         1    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/sre_compile.py:622(_code)
#       504    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/site-packages/numpy/core/fromnumeric.py:2157(_sum_dispatcher)
#       4/1    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/sre_compile.py:87(_compile)
#         6    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/site-packages/zmq/sugar/socket.py:613(send)
#         2    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/logging/__init__.py:932(format)
#         1    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/pstats.py:107(__init__)
#       252    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/site-packages/numpy/core/fromnumeric.py:2797(_amin_dispatcher)
#         2    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/logging/__init__.py:1724(isEnabledFor)
#         1    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/pstats.py:117(init)
#         2    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/logging/__init__.py:1549(findCaller)
#       252    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/site-packages/numpy/core/fromnumeric.py:848(_sort_dispatcher)
#         8    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/threading.py:1169(is_alive)
#       252    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/sre_compile.py:292(_optimize_charset)
#         2    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/logging/__init__.py:665(format)
#         1    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/sre_compile.py:560(_compile_info)
#         2    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/threading.py:545(__init__)
#         2    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/posixpath.py:140(basename)
#         1    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/pstats.py:136(load_stats)
#         8    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/threading.py:1102(_wait_for_tstate_lock)
#         1    0.000    0.000    0.000    0.000 pysam/libcalignmentfile.pyx:2225(__init__)
#         2    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/logging/__init__.py:643(usesTime)
#         2    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/posixpath.py:117(splitext)
#         2    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/threading.py:236(__init__)
#       6/3    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/sre_parse.py:175(getwidth)
#         1    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/logging/__init__.py:219(_acquireLock)
#         2    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/sre_parse.py:97(closegroup)
#         1    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/cProfile.py:50(create_stats)
#        15    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/sre_parse.py:255(get)
#         4    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/posixpath.py:52(normcase)
#         6    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/site-packages/ipykernel/iostream.py:90(_event_pipe)
#       2/1    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/sre_compile.py:485(_get_literal_prefix)
#         1    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/sre_compile.py:435(_mk_bitmap)
#        15    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/sre_parse.py:165(__getitem__)
#         2    0.000    0.000    0.000    0.000 {method 'get_reference_length' of 'pysam.libcalignmentfile.AlignmentFile' objects}
#        18    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/sre_parse.py:234(__next)
#         2    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/logging/__init__.py:649(formatMessage)
#         2    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/sre_parse.py:85(opengroup)
#         2    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/posixpath.py:41(_get_sep)
#         2    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/logging/__init__.py:160(<lambda>)
#         4    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/threading.py:1430(current_thread)
#         1    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/enum.py:986(__and__)
#         8    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/threading.py:553(is_set)
#         2    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/logging/__init__.py:423(usesTime)
#         2    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/logging/__init__.py:438(format)
#         2    0.000    0.000    0.000    0.000 pysam/libcalignmentfile.pyx:1909(get_reference_length)
#         1    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/sre_parse.py:225(__init__)
#         2    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/genericpath.py:121(_splitext)
#         2    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/logging/__init__.py:119(getLevelName)
#        18    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/sre_parse.py:250(match)
#         4    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/logging/__init__.py:912(acquire)
#         4    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/logging/__init__.py:806(filter)
#         1    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/sre_parse.py:433(_uniq)
#         2    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/sre_compile.py:265(_compile_charset)
#         2    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/logging/__init__.py:431(_format)
#         2    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/threading.py:1129(name)
#         1    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/sre_parse.py:76(__init__)
#         7    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/sre_parse.py:287(tell)
#         2    0.000    0.000    0.000    0.000 pysam/libcalignmentfile.pyx:508(get_reference_length)
#         1    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/sre_compile.py:516(_get_charset_prefix)
#         5    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/site-packages/ipykernel/iostream.py:444(_is_master_process)
#         1    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/sre_compile.py:447(_simple)
#         2    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/threading.py:267(__exit__)
#         1    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/sre_compile.py:437(<listcomp>)
#         2    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/enum.py:359(__call__)
#         9    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         2    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/threading.py:276(_acquire_restore)
#         2    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/threading.py:264(__enter__)
#         6    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/sre_parse.py:161(__len__)
#         6    0.000    0.000    0.000    0.000 {method 'find' of 'bytearray' objects}
#         6    0.000    0.000    0.000    0.000 {method 'rfind' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/logging/__init__.py:1710(getEffectiveLevel)
#         1    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/logging/__init__.py:228(_releaseLock)
#         6    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/sre_parse.py:82(groups)
#         4    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/sre_parse.py:173(append)
#         1    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/sre_parse.py:356(_escape)
#         4    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/logging/__init__.py:919(release)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/sre_parse.py:169(__setitem__)
#         2    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/threading.py:273(_release_save)
#         4    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/sre_parse.py:112(__init__)
#         4    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/threading.py:1145(ident)
#         2    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/enum.py:678(__new__)
#         4    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         2    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/sre_compile.py:619(isstring)
#         2    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/logging/__init__.py:359(getMessage)
#         2    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         8    0.000    0.000    0.000    0.000 {built-in method posix.fspath}
#         1    0.000    0.000    0.000    0.000 {built-in method _sre.compile}
#         4    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/sre_compile.py:81(_combine_flags)
#         1    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/logging/__init__.py:1307(disable)
#         1    0.000    0.000    0.000    0.000 {method 'translate' of 'bytearray' objects}
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method fromkeys}
#         1    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/sre_parse.py:928(fix_flags)
#         2    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/threading.py:279(_is_owned)
#         2    0.000    0.000    0.000    0.000 {built-in method sys._getframe}
#         2    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#         2    0.000    0.000    0.000    0.000 {method 'find' of 'str' objects}
#         5    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method time.time}
#         6    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#         9    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#         4    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         3    0.000    0.000    0.000    0.000 pysam/libchtslib.pyx:451(__get__)
#         3    0.000    0.000    0.000    0.000 /iblm/netapp/data2/mcuoco/conda/envs/shell/lib/python3.10/sre_compile.py:477(_get_iscased)
#         2    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 pysam/libcalignmentfile.pyx:2252(__iter__)
#         2    0.000    0.000    0.000    0.000 pysam/libcalignmentfile.pyx:2084(__iter__)

# %%
# sliding window
spc = SlidingWindow(bam, contigs=["chr1"], min_mapq=5)
peaks = []
for p in spc.make_windows(
    size=200,
    step=1,
    min_rpm=2,
    strand_split=True,
    merge=True,
    features=True,
):
    peaks.append(p)

peaks = pd.DataFrame(peaks)

# %%
_, peak_df, line_df = spc.coverage(peaks[peaks["max_mapq"] == 60], line1)

# %%
sns.ecdfplot(data=peak_df, x="diff", hue="Name").set(xscale="log", xlim=1)

# %%
sns.boxplot(data=peak_df, x="alignment_score_mean", y="Name")

# %%
sns.boxplot(data=peak_df, x="num_supp_alignments_mean", y="Name")

# %%
peak_df[(peak_df["Name"] == "NoneNR")]

# %%
peak_df[(peak_df["Name"] == "KNRGL")]

# %% [markdown]
# #### MACS2 (poor coverage of KNRGL and RMSK)

# %%
from subprocess import Popen, PIPE, DEVNULL, CalledProcessError
from tempfile import NamedTemporaryFile, TemporaryDirectory

# %%
def macs2(bam: str, extra: str = ""):
    """
    Run MACS2 on bam file
    """

    names = [
        "Chromosome",
        "Start",
        "End",
        "Name",
        "Score",
        "Strand",
        "signalValue",
        "pValue",
        "qValue",
        "peak",
    ]

    with TemporaryDirectory() as tmpdir:
        cmd = f"macs2 callpeak -t {bam} -g hs --outdir {tmpdir} --name test {extra}"
        try:
            Popen(cmd, shell=True).communicate()
        except CalledProcessError as e:
            print(e.output)

        df = pd.read_csv(
            f"{tmpdir}/test_peaks.narrowPeak", sep="\t", header=None, names=names
        )

        df["width"] = df["End"] - df["Start"]

    return df

# %%
with NamedTemporaryFile(suffix=".bam") as tmpfile:
    Popen(
        f"samtools view -bh -F 2052 {bam}", shell=True, stdout=tmpfile, stderr=PIPE
    ).communicate()
    tmpfile.seek(0)
    peaks = macs2(tmpfile.name, extra="-f BAMPE --nolambda --nomodel --extsize 50")

# %% [markdown]
# ## Single-cell Peaks

# %%
bam = pysam.AlignmentFile(indv_data["1"]["cells"][0])
knrgl = pd.read_csv(indv_data["1"]["knrgl"], sep="\t")
knrgl["Name"] = "KNRGL"
line1 = pd.concat(
    [
        knrgl[["Chromosome", "Start", "End", "Name"]],
        rmsk[["Chromosome", "Start", "End", "Name"]],
    ]
).sort_values(["Chromosome", "Start", "End"])

# %%
# sliding window
spc = SlidingWindow(bam, contigs=["chr1"], min_mapq=5)
peaks = []
for p in spc.make_windows(
    size=200,
    step=1,
    min_rpm=2,
    strand_split=True,
    merge=True,
    features=False,
):
    peaks.append(p)

peaks = pd.DataFrame(peaks)

# %%
_, peak_df, line_df = spc.coverage(peaks[peaks["max_mapq"] == 60], line1)

# %%
sns.ecdfplot(data=peak_df, x="diff", hue="Name").set(xscale="log", xlim=1)
